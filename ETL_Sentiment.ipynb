# %% [markdown]
# # SENTIMENT ANALYSIS

# %%
## Import needed libraries
import pandas as pd #Dataframes
import numpy as np #Numerics
import json #JSON
import ast #Eval datatype
import gzip ##
from textblob import TextBlob## NPL
import re

# %%
## Read dataset
df_sen=pd.read_csv("Dataset/Cleaned_Dataset/user_reviews.csv")

# %%
df_sen## Dataset view
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 2      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 3                js41637               http://steamcommunity.com/id/js41637
# 4                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 59328  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59329  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59330        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59331        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59332        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
# ...

# %%
df_sen["review"][df_sen["review"].isnull()]="Neutral Comment"##Fill NaN values in review collumn with "Neutral Comment" to get Sentiment analysis 1

# %%
df_sen[df_sen["review"]=="Neutral Comment"] ##View dataframe with column review is "Neutral Comment"
# Out:
#                    user_id                                           user_url  \
# 137                  gdxsd                 http://steamcommunity.com/id/gdxsd
# 177      76561198094224872  http://steamcommunity.com/profiles/76561198094...
# 2559     76561198021575394  http://steamcommunity.com/profiles/76561198021...
# 3098             2ZESTY4ME             http://steamcommunity.com/id/2ZESTY4ME
# 4619     76561198093337643  http://steamcommunity.com/profiles/76561198093...
# 10080              cmuir37               http://steamcommunity.com/id/cmuir37
# 13767            Jaysteeny             http://steamcommunity.com/id/Jaysteeny
# 15493               ML8989                http://steamcommunity.com/id/ML8989
# 15981           terencemok            http://steamcommunity.com/id/terencemok
# 19184    76561198079215291  http://steamcommunity.com/profiles/76561198079...
# 20223    76561198079342142  http://steamcommunity.com/profiles/76561198079...
# ...

# %%
## Function to clean column review
def clean_text(text):
    # This code uses a regular expression to remove everything other than text and whitespace
    cleaned_text = re.sub(r'[^a-zA-Z\s]', '', text)
    return cleaned_text

# Aply this function to column review
df_sen['review'] = df_sen['review'].apply(clean_text)

# %%
df_sen ## view dataset
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 2      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 3                js41637               http://steamcommunity.com/id/js41637
# 4                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 59328  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59329  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59330        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59331        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59332        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
# ...

# %% [markdown]
# ## Sentiment_analysis

# %% [markdown]
# ### Using textblob library

# %%
# Funcióntion to clasify reviews
def classify_sentiment(polarity):
    if polarity < -0.2:
        return 0 ## Negative
    elif polarity > 0.2:
        return 2 ## Positive
    else:
        return 1 ## Neutral


##Aply this function and create new column "sentiment_analysis"
df_sen['sentiment_analysis'] = df_sen['review'].apply(lambda x: classify_sentiment(TextBlob(x).sentiment.polarity))

# %%
df_sen## Dataset view
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 2      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 3                js41637               http://steamcommunity.com/id/js41637
# 4                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 59328  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59329  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59330        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59331        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59332        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
# ...

# %% [markdown]
# ### Export Dataset

# %%
df_sen.to_csv("Dataset/Cleaned_Dataset/user_reviews_sent.csv",index=False)
